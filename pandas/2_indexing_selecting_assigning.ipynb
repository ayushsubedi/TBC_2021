# %% [markdown]
# ### Topics
#
# - native accessors
# - indexing
# - iloc vs loc
# - label based selection
# - setting index
# - conditional selection
# - assigning data

# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
filter_list = ['Name', 'Age']
df[filter_list]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
df['PassengerId'] = df['PassengerId']*10

# %%
df.set_index('PassengerId', inplace=True)

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 10                  0       3
# 20                  1       1
# 30                  1       3
# 40                  1       1
# 50                  0       3
# ...               ...     ...
# 8870                0       2
# 8880                1       1
# 8890                0       3
# 8900                1       1
# 8910                0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 10                                     Braund, Mr. Owen Harris    male  22.0
# 20           Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 30                                      Heikkinen, Miss. Laina  female  26.0
# 40                Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 50                                    Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.loc[20]
# Out:
# Survived                                                    1
# Pclass                                                      1
# Name        Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                    female
# Age                                                        38
# SibSp                                                       1
# Parch                                                       0
# Ticket                                               PC 17599
# Fare                                                  71.2833
# Cabin                                                     C85
# Embarked                                                    C
# Name: 20, dtype: object

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 10                  0       3
# 20                  1       1
# 30                  1       3
# 40                  1       1
# 50                  0       3
# ...               ...     ...
# 8870                0       2
# 8880                1       1
# 8890                0       3
# 8900                1       1
# 8910                0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 10                                     Braund, Mr. Owen Harris    male  22.0
# 20           Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 30                                      Heikkinen, Miss. Laina  female  26.0
# 40                Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 50                                    Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df[df.Sex=='male']
# Out:
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 10                  0       3         Braund, Mr. Owen Harris  male  22.0
# 50                  0       3        Allen, Mr. William Henry  male  35.0
# 60                  0       3                Moran, Mr. James  male   NaN
# 70                  0       1         McCarthy, Mr. Timothy J  male  54.0
# 80                  0       3  Palsson, Master. Gosta Leonard  male   2.0
# ...               ...     ...                             ...   ...   ...
# 8840                0       2   Banfield, Mr. Frederick James  male  28.0
# 8850                0       3          Sutehall, Mr. Henry Jr  male  25.0
# 8870                0       2           Montvila, Rev. Juozas  male  27.0
# 8900                1       1           Behr, Mr. Karl Howell  male  26.0
# 8910                0       3             Dooley, Mr. Patrick  male  32.0
#
# ...

# %%
df[(df.Sex=='male') & (df.Age>70)]
# Out:
#              Survived  Pclass                                  Name   Sex  \
# PassengerId
# 970                 0       1             Goldschmidt, Mr. George B  male
# 1170                0       3                  Connors, Mr. Patrick  male
# 4940                0       1               Artagaveytia, Mr. Ramon  male
# 6310                1       1  Barkworth, Mr. Algernon Henry Wilson  male
# 8520                0       3                   Svensson, Mr. Johan  male
#
#               Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# PassengerId
# 970          71.0      0      0  PC 17754  34.6542    A5        C
# 1170         70.5      0      0    370369   7.7500   NaN        Q
# 4940         71.0      0      0  PC 17609  49.5042   NaN        C
# 6310         80.0      0      0     27042  30.0000   A23        S
# 8520         74.0      0      0    347060   7.7750   NaN        S

# %%
df[df.Age<1]
# Out:
#              Survived  Pclass                             Name     Sex   Age  \
# PassengerId
# 790                 1       2    Caldwell, Master. Alden Gates    male  0.83
# 3060                1       1   Allison, Master. Hudson Trevor    male  0.92
# 4700                1       3    Baclini, Miss. Helene Barbara  female  0.75
# 6450                1       3           Baclini, Miss. Eugenie  female  0.75
# 7560                1       2        Hamalainen, Master. Viljo    male  0.67
# 8040                1       3  Thomas, Master. Assad Alexander    male  0.42
# 8320                1       2  Richards, Master. George Sibley    male  0.83
#
#              SibSp  Parch  Ticket      Fare    Cabin Embarked
# PassengerId
# 790              0      2  248738   29.0000      NaN        S
# 3060             1      2  113781  151.5500  C22 C26        S
# 4700             2      1    2666   19.2583      NaN        C
# 6450             2      1    2666   19.2583      NaN        C
# ...
